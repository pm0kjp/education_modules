# %% [markdown]
# # Data Analysis in Python: Data Import
#
# Before analyzing your data in Python, you need to import it! This notebook will show you a variety of ways to import data from a variety of sources.
#
# ## Tabular data
#
# Sometimes, you'll be

# %%
import pandas as pd

# %%
covid_testing = pd.read_csv("covid_testing.csv")
covid_testing
# Out:
#            mrn  first_name   last_name  gender  pan_day test_id  \
# 0      5001412     jhezane  westerling  female        4   covid
# 1      5000533       penny   targaryen  female        7   covid
# 2      5009134       grunt      rivers    male        7   covid
# 3      5008518  melisandre       swyft  female        8   covid
# 4      5008967      rolley    karstark    male        8   covid
# ...        ...         ...         ...     ...      ...     ...
# 15519  5011798       leona       royce  female      107   covid
# 15520  5011986       gilly       tarly  female      107   covid
# 15521  5012174     barbrey    manderly  female      107   covid
# 15522  5012191      walder       tully    male      107   covid
# 15523  5012328       jeyne   baratheon  female      107   covid
#
#              clinic_name    result   demo_group   age  drive_thru_ind  \
# 0       inpatient ward a  negative      patient   0.0               0
# ...

# %%
covid_testing.dtypes
# Out:
# mrn                 int64
# first_name         object
# last_name          object
# gender             object
# pan_day             int64
# test_id            object
# clinic_name        object
# result             object
# demo_group         object
# age               float64
# drive_thru_ind      int64
# ct_value          float64
# orderset            int64
# payor_group        object
# patient_class      object
# col_rec_tat       float64
# rec_ver_tat       float64
# dtype: object

# %%
covid_testing_csv = pd.read_table("covid_testing.csv", sep = ",")
covid_testing_csv
# Out:
#            mrn  first_name   last_name  gender  pan_day test_id  \
# 0      5001412     jhezane  westerling  female        4   covid
# 1      5000533       penny   targaryen  female        7   covid
# 2      5009134       grunt      rivers    male        7   covid
# 3      5008518  melisandre       swyft  female        8   covid
# 4      5008967      rolley    karstark    male        8   covid
# ...        ...         ...         ...     ...      ...     ...
# 15519  5011798       leona       royce  female      107   covid
# 15520  5011986       gilly       tarly  female      107   covid
# 15521  5012174     barbrey    manderly  female      107   covid
# 15522  5012191      walder       tully    male      107   covid
# 15523  5012328       jeyne   baratheon  female      107   covid
#
#              clinic_name    result   demo_group   age  drive_thru_ind  \
# 0       inpatient ward a  negative      patient   0.0               0
# ...
